# %%
print(123)
# Out:
# 123

# %%
import ray 

import time

database = [
    "Learning", "Ray",
    "Flexible", "Distributed", "Python", "for", "Machine", "Learning"
]


def retrieve(item):
    time.sleep(item / 10.)
    return item, database[item]

# ray task = a function that ray executes on a different process from 
# where it was called, possibly on different machine

# intended use: func.remote()
@ray.remote 
def retrieve_task(item):
    return retrieve(item)

def print_runtime(input_data, start_time):
    print(f'Runtime: {time.time() - start_time:.2f} seconds, data:')
    print(*input_data, sep="\n")
    
start = time.time()
object_references = [
    retrieve_task.remote(item) for item in range(8)
]
data = ray.get(object_references)
print_runtime(data, start)
# Out:
# 2025-11-16 19:06:18,831	INFO worker.py:2003 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_private/worker.py:2051: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# Runtime: 7.07 seconds, data:
# (0, 'Learning')
# (1, 'Ray')
# (2, 'Flexible')
# (3, 'Distributed')
# (4, 'Python')
# (5, 'for')
# (6, 'Machine')
# (7, 'Learning')

# %%
import ray 

# ray task = a function that ray executes on a different process from 
# where it was called, possibly on different machine

# intended use: func.remote()
@ray.remote 
def retrieve_task(item):
    return retrieve(item)

def print_runtime(input_data, start_time):
    print(f'Runtime: {time.time() - start_time:.2f} seconds, data:')
    print(*input_data, sep="\n")
    
start = time.time()
object_references = [
    retrieve_task.remote(item) for item in range(8)
]

data = ray.get(object_references)
print_runtime(data, start)
# Out:
# Runtime: 0.71 seconds, data:
# (0, 'Learning')
# (1, 'Ray')
# (2, 'Flexible')
# (3, 'Distributed')
# (4, 'Python')
# (5, 'for')
# (6, 'Machine')
# (7, 'Learning')

# %%
import os
import multiprocessing

print("multiprocessing count:", multiprocessing.cpu_count())
print("os cpu count:", os.cpu_count())
# Out:
# multiprocessing count: 32
# os cpu count: 32
# *** SIGBUS received at time=1763345181 on cpu 22 ***
# PC: @     0x7f433f639050  (unknown)  (unknown)
#     @     0x7f4369c3e730       3536  (unknown)
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f97f340, start_addr: 7f433e3f9000
#     @     0x7f433f97f341         96  (unknown)
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f89869b, start_addr: 7f433e3f9000
#     @     0x7f433f89869c        144  _GLOBAL_OFFSET_TABLE_
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f8988a6, start_addr: 7f433e3f9000
#     @     0x7f433f8988a7        144  _GLOBAL_OFFSET_TABLE_
#     @     0x7f433f593f54        368  kOpenSSLReasonValues
#     @     0x7f433f594b6b        144  grpc_core::InternallyRefCounted<>
#     @     0x7f433f59a66b        144  (unknown)
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f9668d3, start_addr: 7f433e3f9000
#     @     0x7f433f9668d4         96  (unknown)
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f9688fd, start_addr: 7f433e3f9000
#     @     0x7f433f9688fe         80  (unknown)
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f8fba93, start_addr: 7f433e3f9000
#     @     0x7f433f8fba94       1120  (unknown)
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f8fcd69, start_addr: 7f433e3f9000
#     @     0x7f433f8fcd6a        208  (unknown)
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f8f63b9, start_addr: 7f433e3f9000
#     @     0x7f433f8f63ba         32  (unknown)
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f8f60b9, start_addr: 7f433e3f9000
#     @     0x7f433f8f60ba         32  (unknown)
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433f8b7bbf, start_addr: 7f433e3f9000
#     @     0x7f433f8b7bc0        272  __pyx_mdef_3ray_7_raylet_6Config_79nums_py_gcs_reconnect_retry
#     @     0x7f433f411e61         64  inflate
#     @     0x7f433eff74f3       1200  std::vector<>::_M_realloc_insert<>()
# [symbolize_elf.inc : 1424] RAW: /home/bs82/max-k-cut-parallel/ray/lib/python3.10/site-packages/ray/_raylet.so: unable to find LOAD segment for pc: 0x7f433fa10d7f, start_addr: 7f433e3f9000
#     @     0x7f433fa10d80  (unknown)  (unknown)
#     @ ... and at least 3 more frames
# [2025-11-16 20:06:21,551 E 779277 782919] logging.cc:474: *** SIGBUS received at time=1763345181 on cpu 22 ***
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
